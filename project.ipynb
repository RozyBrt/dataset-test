# %%
import pandas as pd

# %%
dataset = pd.read_csv("mxmh_survey_results.csv")
dataset
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# ...

# %%
hapuskolom = ["Age", "Composer", "Exploratory"]
dataset.drop(columns=hapuskolom,inplace=True)

# %%
dataset
# Out:
#                Timestamp Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02                   Spotify            3.0
# 1     8/27/2022 19:57:31                   Pandora            1.5
# 2     8/27/2022 21:28:18                   Spotify            4.0
# 3     8/27/2022 21:40:40             YouTube Music            2.5
# 4     8/27/2022 21:54:47                   Spotify            4.0
# ..                   ...                       ...            ...
# 731  10/30/2022 14:37:28                   Spotify            2.0
# 732   11/1/2022 22:26:42                   Spotify            1.0
# 733   11/3/2022 23:24:38   Other streaming service            6.0
# 734   11/4/2022 17:31:47                   Spotify            5.0
# 735    11/9/2022 1:55:20             YouTube Music            2.0
#
#     While working Instrumentalist         Fav genre Foreign languages    BPM  \
# 0             Yes             Yes             Latin               Yes  156.0
# ...
